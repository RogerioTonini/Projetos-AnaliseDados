# %%
""" 
# ALURA - Desafio: 7DaysOfCode
#
# Dia 2 
# Alterar tipagem da coluna [matricula_e_siape]
# Exclusão da coluna [registro_sistema]
# Crição uma nova coluna com os valores da localização, para refletir a respectiva classe geral na CDU.
"""
import pandas as pd
import os

_strDB_CDU        = 'DB_CDU'
_strDB_Emprestimo = 'DB_Emprestimo_Tratado'
_strDB_Tratado_2  = 'DB_Emprestimo_Tratado_2'
_strExtArquivo    = '.csv'
_strPathData      = r'D:\Users\rtoni\OneDrive\Git-Dados\Projetos\7DaysOfCode.io'

# %%
""" 
# Carga dos Dados para os DataFrames
# Demonstra informações dados do Cadastro de Livros
"""
_strPathFile = os.path.join(_strPathData, _strDB_Emprestimo + _strExtArquivo)
df_Emprestimo_Tratado_2 = pd.read_csv(_strPathFile, sep=';', engine='c')

_strPathFile = os.path.join(_strPathData, _strDB_CDU + _strExtArquivo)
df_CDU = pd.read_csv(_strPathFile, sep=';', engine='c')

df_Emprestimo_Tratado_2.info()
df_Emprestimo_Tratado_2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072522 entries, 0 to 2072521
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  registro_sistema      int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 205.6+ MB
#    id_emprestimo codigo_barras           data_renovacao  \
# 0         709684       L095049                      NaN
# 1         726965       L095049  2010-03-31 12:41:08.684
# 2         709685       L167050                      NaN
# ...

# %%
""" 
# Alterar tipagem da coluna [matricula_e_siape]
# Exclusão da coluna [registro_sistema]
"""
df_Emprestimo_Tratado_2['matricula_ou_siape'] = df_Emprestimo_Tratado_2['matricula_ou_siape'].astype(str)
df_Emprestimo_Tratado_2.drop(columns='registro_sistema')

df_Emprestimo_Tratado_2.info()
df_Emprestimo_Tratado_2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072522 entries, 0 to 2072521
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  registro_sistema      int64
# dtypes: int64(4), object(9)
# memory usage: 205.6+ MB
#    id_emprestimo codigo_barras           data_renovacao  \
# 0         709684       L095049                      NaN
# 1         726965       L095049  2010-03-31 12:41:08.684
# 2         709685       L167050                      NaN
# ...

# %%
df_CDU.info()
df_CDU.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_FaixaCDU     10 non-null     int64
#  1   Inicio_Faixa    10 non-null     int64
#  2   Limite_Faixa    10 non-null     int64
#  3   Nome_Faixa_CDU  10 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 448.0+ bytes
#    ID_FaixaCDU  Inicio_Faixa  Limite_Faixa  \
# 0            1             0            99
# 1            2           100           199
# 2            3           200           299
# 3            4           300           399
# 4            5           400           499
#
#                               Nome_Faixa_CDU
# 0      Generalidades. Ciência e conhecimento
# 1                    Filosofia e psicologia.
# 2                                  Religião.
# 3                          Ciências sociais.
# 4  Classe vaga. Provisoriamente não ocupada.
